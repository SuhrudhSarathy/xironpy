# %% [markdown]
# ## Exploring Xiron's Python Interface

# %% [markdown]
# ### XironContext
# XironContext is the main Class that connect to the Xiron Simulator using Websockets. It provides utility functions to get messages from the simulator and send messages to the simulator

# %%
from xiron_py.comms import XironContext
from xiron_py.data import LaserScan, Pose, Twist

# %%
# Create the main ctx object
ctx = XironContext()
# Out:
# Initialised the main communicator

# %%
ctx.run_in_separate_thread()
# Out:
# Signal handler is not added. Make sure to call `stop` function to stop the websockets properly
# Connected to S2C WebSocket
# Connected to C2S WebSocket

# %% [markdown]
# ### Get Pose
# The `get_pose` function can be called to get the last received pose of a robot as `Pose` msg. A callback function can also be registered using the `create_scan_subscriber` function.

# %%
pose: Pose = ctx.get_pose("robot0")
print(f"Received Pose: {pose}")
# Out:
# Received Pose: Pose(timestamp=1742352369.589491, robot_id='robot0', position=[-5.957324028015137, 1.9695310592651367], orientation=0.0)

# %% [markdown]
# ### Get Scan
# The `get_scan` function can be called to get the last received scan as `LaserScan` msg from a robot. A callback function can also be registered using the `create_scan_subscriber` function

# %%
scan: LaserScan = ctx.get_scan("robot1")
print(f"Received Scan: {scan}")
# Out:
# Received Scan: LaserScan(timestamp=1742352370.808053, robot_id='robot1', angle_min=-3.1415927410125732, angle_max=3.1415927410125732, num_readings=360, values=[2.6272854804992676, 2.6532857418060303, 2.6160244941711426, 2.703897714614868, 2.6440436840057373, 2.7206742763519287, 4.013902187347412, 3.958359956741333, 3.986525297164917, 3.992473602294922, 4.0358757972717285, 4.062296390533447, 4.063478946685791, 4.122314453125, 4.141162395477295, 4.158857822418213, 4.094527721405029, 4.163261413574219, 4.229129791259766, 4.254025936126709, 4.261990547180176, 4.261970043182373, 4.301837921142578, 4.30668830871582, 4.348489761352539, 4.416143894195557, 4.514543533325195, 4.372835159301758, 4.287275791168213, 4.091892242431641, 4.0218424797058105, 3.8963191509246826, 3.7743313312530518, 3.6431562900543213, 3.5832247734069824, 3.5292630195617676, 3.3937737941741943, 3.313214063644409, 3.2853691577911377, 3.250284194946289, 3.148803949356079, 3.0501809120178223, 3.003602981567383, 2.9556665420532227, 2.9079062938690186, 2.830104351043701, 2.8428261280059814, 2.7941057682037354, 2.7396810054779053, 2.686385154724121, 2.6344380378723145, 2.6507232189178467, 2.580822706222534, 2.5545692443847656, 2.510988712310791, 2.4304416179656982, 2.4967939853668213, 2.3776707649230957, 2.422583818435669, 2.3399007320404053, 2.327268362045288, 2.304412603378296, 2.2593026161193848, 2.3236005306243896, 2.2644591331481934, 2.2064578533172607, 2.2695300579071045, 2.2412803173065186, 2.2250592708587646, 2.1731879711151123, 2.2029383182525635, 2.1359124183654785, 2.1705567836761475, 2.094372272491455, 2.1386260986328125, 2.15954327583313, 2.135211706161499, 2.0806703567504883, 2.0849063396453857, 2.1169235706329346, 2.0861377716064453, 2.0713255405426025, 2.1077170372009277, 2.0748322010040283, 2.060971736907959, 2.006420850753784, 2.06007719039917, 2.081144332885742, 2.0788450241088867, 2.0789408683776855, 2.05110502243042, 2.0846595764160156, 2.0095043182373047, 2.04660701751709, 2.0377423763275146, 2.097198247909546, 2.0940234661102295, 2.0485804080963135, 2.0798003673553467, 2.1057748794555664, 2.07560396194458, 2.0509538650512695, 2.048257827758789, 2.1346356868743896, 2.0661444664001465, 2.101489782333374, 2.148595094680786, 2.1032052040100098, 2.1905274391174316, 2.1800332069396973, 2.1610074043273926, 2.24808406829834, 2.2252776622772217, 2.23738169670105, 2.223980665206909, 2.31738543510437, 2.2959601879119873, 6.771378993988037, 6.842935085296631, 6.934471130371094, 6.950376987457275, 7.033144950866699, 7.11959171295166, 7.221332550048828, 7.2639594078063965, 7.349478721618652, 7.455184459686279, 7.524314880371094, 7.662036418914795, 7.7367963790893555, 7.916999340057373, 8.016462326049805, 8.101531982421875, 8.249238967895508, 8.384243965148926, 8.508432388305664, 8.702683448791504, 8.872271537780762, 9.028207778930664, 9.208515167236328, 9.447603225708008, 9.645718574523926, 9.832082748413086, 20.039377212524414, 9.904600143432617, 9.772391319274902, 9.676280975341797, 9.589561462402344, 9.507341384887695, 9.342757225036621, 9.27590560913086, 9.235671997070312, 9.168488502502441, 9.012652397155762, 8.987264633178711, 8.861592292785645, 8.838444709777832, 4.286806583404541, 4.186746120452881, 4.202162265777588, 4.140632629394531, 4.092543125152588, 4.0742950439453125, 4.122717380523682, 4.0703935623168945, 4.078291416168213, 4.043812274932861, 4.041253566741943, 3.969646692276001, 4.022500514984131, 3.9406521320343018, 3.9555327892303467, 3.9128453731536865, 3.9764864444732666, 3.922576904296875, 3.929666519165039, 3.9142966270446777, 3.86775803565979, 3.9607625007629395, 3.889965057373047, 3.883547782897949, 3.866288661956787, 3.8647561073303223, 3.9036977291107178, 3.9590580463409424, 3.928846597671509, 3.982637405395508, 3.925621271133423, 3.9942359924316406, 3.9388811588287354, 4.004491806030273, 3.9672412872314453, 3.964735746383667, 3.983353614807129, 4.041868686676025, 4.074214935302734, 4.061763763427734, 2.7601723670959473, 2.573362827 ...

# %% [markdown]
# ### Send Velocity
# Velocity in the form of `Twist` message can be sent to the simulator using the `publish_velocity` function.

# %%
msg = Twist(timestamp=ctx.now(), robot_id="robot0", linear=(0.1, 0.0), angular=0.5)
ctx.publish_velocity(msg)

# %%
msg = Twist(timestamp=ctx.now(), robot_id="robot1", linear=(0.1, 0.1), angular=0.5)
ctx.publish_velocity(msg)

# %%
msg = Twist(timestamp=ctx.now(), robot_id="robot2", linear=(0.1, -0.5), angular=0.0)
ctx.publish_velocity(msg)

# %%
msg = Twist(timestamp=ctx.now(), robot_id="robot3", linear=(-0.1, -0.5), angular=0.0)
ctx.publish_velocity(msg)

# %% [markdown]
# ### Reset Simulation

# %% [markdown]
# The `reset_simulation` API restores the simulator to its initial state. If no configuration file was loaded and the world was generated interactively, this function resets the simulation to a blank state.

# %%
ctx.reset_simulation()
